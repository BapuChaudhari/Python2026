# %% [markdown]
# 1. Write a program to add two lists index-wise. Create a new list that contains the 0th index item from both the list, then the 1st index item, and so on till the last element. any leftover items will get added at the end of the new list.
#
# 	Given List:
#
# 	list1 = ["M", "na", "i", "Ra"]
# 	list2 = ["y", "me", "s", "hul"]
#
# 	Output:
#
# 	[['M','y'], ['na', me'], ['i', 's'], ['Ra', 'hul']]

# %%
list1 = ["M", "na", "i", "Ra"]
list2 = ["y", "me", "s", "hul"]

zip(list1,list2)
print(list(zip(list1,list2)))
# Out:
# [('M', 'y'), ('na', 'me'), ('i', 's'), ('Ra', 'hul')]

# %%
list1 = ["M", "na", "i", "Ra"]
list2 = ["y", "me", "s", "hul"]

result=[[a,b] for a, b in zip(list1,list2)]
print(result)
# Out:
# [['M', 'y'], ['na', 'me'], ['i', 's'], ['Ra', 'hul']]

# %% [markdown]
# 2. Write a program to add item 7000 after 6000 in the following Python List
#
# 	list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
#
# 	Output:
#
# 	[10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %%
list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
list1[2][2].append(7000)
print(list1)
# Out:
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %% [markdown]
# 3. Suppose you are given a list of candy and another list of same size representing no of items of respective candy.
#
# 	i.e -
#
# 	candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
# 	no_of_items = [10,20,34,74,32]
# 	Write a program to show no. of items of each candy type.
#
# 	Output:
#
# 	Jelly Belly-10
# 	Kit Kat-20
# 	Double Bubble-34
# 	Milky Way-74
# 	Three Musketeers-32

# %%
candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
no_of_items = [10,20,34,74,32]
result=[[a,b] for a,b in zip(candy_list,no_of_items) ]
for i in result:
  print(i[0] ,"-",i[1])
# Out:
# Jelly Belly - 10
# Kit Kat - 20
# Double Bubble - 34
# Milky Way - 74
# Three Musketeers - 32

# %%
candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
no_of_items = [10,20,34,74,32]
for i in range(len(candy_list)):
  print(candy_list[i] ,'-',no_of_items[i])
# Out:
# Jelly Belly - 10
# Kit Kat - 20
# Double Bubble - 34
# Milky Way - 74
# Three Musketeers - 32

# %% [markdown]
# 4. Running Sum on list Write a program to print a list after performing running sum on it.
#
# 	i.e:
#
# 	Input:
#
# 	list1 = [1,2,3,4,5,6]
#
# 	Output:
#
# 	[1,3,6,10,15,21]

# %%
list1 = [1,2,3,4,5,6]
running_sum=0
output=[]
for i in list1:
  running_sum=running_sum + i
  output.append(running_sum)
print(output)
# Out:
# [1, 3, 6, 10, 15, 21]

# %% [markdown]
# 5. You are given a list of integers. You are asked to make a list by running through elements of the list by adding all elements greater and itself.
#
# 	i.e. Say given list is [2,4,6,10,1] resultant list will be [22,20,10,23].
#
# 	For 1st element 2 ->> these are greater (4+6+10) values and 2 itself so on adding becomes 22.
#
# 	For 2nd element 4 ->> greater elements are (6, 10) and 4 itself, so on adding 20
#
# 	like wise for all other elememts.
#
# 	[2,4,6,10,1]-->[22,20,16,10,23]

# %%
list1 =[]
result=[]
print('press 0 for end')
while True:
  num = int(input('enter a number to be added in list  = '))
  if num==0:
    break
  else:
    list1.append(num)
for i in list1:
  sum=0
  for j in list1:
    if i<j:
      sum=sum+j
  sum=sum+i
  result.append(sum)

print(list1)
print(result)
# Out:
# press 0 for end
# enter a number to be added in list  = 2
# enter a number to be added in list  = 3
# enter a number to be added in list  = 4
# enter a number to be added in list  = 5
# enter a number to be added in list  = 6
# enter a number to be added in list  = 0
# [2, 3, 4, 5, 6]
# [20, 18, 15, 11, 6]

# %% [markdown]
# 6. Find list of common unique items from two list. and show in increasing order
#
# 	Input
#
# 	num1 = [23,45,67,78,89,34]
#
# 	num2 = [34,89,55,56,39,67]
#
# 	Output:
#
# 	[34, 67, 89]

# %%
#list of common unique items from two list
a =[]
b =[]
result =[]
print('press 0 for end')
while True:
  num = int(input('enter element of list a  = '))
  if num==0:
    break
  else:
    a.append(num)
while True:
  num = int(input('enter element of list b  = '))
  if num==0:
    break
  else:
    b.append(num)
for i in a:
  for j in b:
    if i == j:
      result.append(i)
    else:
      pass
if not result:
   c='no common found'
   result.append(c)

print(a)
print(b)
print(sorted(result))
# Out:
# press 0 for end
# enter element of list a  = 23
# enter element of list a  = 45
# enter element of list a  = 67
# enter element of list a  = 78
# enter element of list a  = 89
# enter element of list a  = 34
# enter element of list a  = 0
# enter element of list b  = 34
# enter element of list b  = 89
# enter element of list b  = 55
# enter element of list b  = 56
# enter element of list b  = 39
# enter element of list b  = 67
# enter element of list b  = 0
# [23, 45, 67, 78, 89, 34]
# [34, 89, 55, 56, 39, 67]
# [34, 67, 89]

# %% [markdown]
# 7. Sort a list of alphanumeric strings based on product value of numeric character in it. If in any string there is no numeric character take it's product value as 1.
#
# 	Input:
#
# 	['1ac21', '23fg', '456', '098d','1','kls']
#
# 	Output:
#
# 	['456', '23fg', '1ac21', '1', 'kls', '098d']

# %%
l=['1ac21', '23fg', '456', '098d','1','kls']

# %% [markdown]
# 8. Write a program that can find the max number of each row of a matrix
# 	Example:
#
# 	Input:
#
# 	[[1,2,3],[4,5,6],[7,8,9]]
#
# 	Output:
#
# 	[3,6,9]

# %%
l=[[1,2,3],[4,5,6],[7,8,9]]
list1=[]

for i in l:
  sum= max(i)

  list1.append(sum)
print(list1)
# Out:
# [3, 6, 9]

# %% [markdown]
# 9. Shortlist Students for a Job role Ask user to input students record and store in tuples for each record. Then Ask user to input three things he wants in the candidate- Primary Skill, Higher Education, Year of Graduation.
#
# 	Show every students record in form of tuples if matches all required criteria.
#
# 	It is assumed that there will be only one primry skill.
#
# 	If no such candidate found, print No such candidate
#
# 	Input:
#
# 	Enter No of records- 2
#
# 	Enter Details of student-1
#
# 	Enter Student name- Manohar
#
# 	Enter Higher Education- B.Tech
#
# 	Enter Primary Skill- Python
#
# 	Enter Year of Graduation- 2022
#
# 	Enter Details of student-2
#
# 	Enter Student name- Ponian
#
# 	Enter Higher Education- B.Sc.
#
# 	Enter Primary Skill- C++
#
# 	Enter Year of Graduation- 2020
#
# 	Enter Job Role Requirement
#
# 	Enter Skill- Python
#
# 	Enter Higher Education- B.Tech
#
# 	Enter Year of Graduation- 2022
#
# 	Output
#
# 	('Manohar', 'B.tech', 'Python', '2022')

# %%
list1=[]
# enter number of candidate
n = int(input("enter number of records = "))

for i in range(0,n):

  #enter students details
  print("\n enter details of student {} = ".format(i+1))
  name = input(" enter name = ")
  higher_education = input("enter higher education = ")
  primary_skill = input('enter primary skill = ')
  graduation_year = input('enter graduation year = ')

  tuple1=( name, higher_education, primary_skill, graduation_year)
  list1.append(tuple1)
print(list1)

# enter required details
print('\n enter job role requirement')
education = input('enter higher education ')
skill = input('enter skill required = ')
year = input('enter year of graduation = ')

found = False
# matching details
for i in list1:
  if i[1]== education and i[2]==skill and i[3]== year :
    print(i)
    found = True
  else:
    pass

if not found :
  print('no such candidate')
# Out:
# enter number of records = 2
#
#  enter details of student 1 =
#  enter name = bapu
# enter higher education = be
# enter primary skill = python
# enter graduation year = 2016
#
#  enter details of student 2 =
#  enter name = sanchu
# enter higher education = mba
# enter primary skill = c++
# enter graduation year = 2020
# [('bapu', 'be', 'python', '2016'), ('sanchu', 'mba', 'c++', '2020')]
#
#  enter job role requirement
# enter higher education be
# enter skill required = python
# enter year of graduation = 2016
# ('bapu', 'be', 'python', '2016')

# %% [markdown]
# 10. Write a program to find set of common elements in three lists using sets.
#
# 	Input :
#
#      ar1 = [1, 5, 10, 20, 40, 80]
#
# 		 ar2 = [6, 7, 20, 80, 100]
#
# 		 ar3 = [3, 4, 15, 20, 30, 70, 80, 120]
#
# 	Output : [80, 20]

# %%
ar1 = [1, 5, 10, 20, 40, 80]
ar2 = [6, 7, 20, 80, 100 ]
ar3 = [3, 4, 15, 20, 30, 70, 80, 120]
common = list(set(ar1) & set(ar2) & set(ar3))
print('common element in list = ',common)
# Out:
# common element in list =  [80, 20]

# %%
ar1 = [1, 5, 10, 20, 40, 80]
ar2 = [6, 7, 20, 80, 100 ]
ar3 = [3, 4, 15, 20, 30, 70, 80, 120]
common=[i for i in ar1 if i in ar2 ]
common=[i for i in common if i in ar3]
print('common element =  \n', common )
# Out:
# common element =
#  [20, 80]

# %% [markdown]
# 11. Write a program to count unique number of vowels using sets in a given string. Lowercase and upercase vowels will be taken as different.
#
# 	Input:
#
# 	Str1 = "hands-on data science mentorship progrAm with live classes at affordable fee only on CampusX"
#
# 	Output:
#
# 	No of unique vowels-6

# %%
str1 = 'hands-on data science mentorship progrAm with live classes at affordable fee only on CampusX'
vovels ={'a','e','i','o','u','A'}
l=[]
s=set()
for i in str1:
  if i in vovels:
    s.add(i)
print(len(s))
# Out:
# 6

# %%
str1 = 'hands-on data science mentorship progrAm with live classes at affordable fee only on CampusX'
vovels ={'a','e','i','o','u','A'}
l=set(str1)
count = len(l.intersection(vovels))
print(count)
# Out:
# 6

# %% [markdown]
# 12. Intersection of two lists. Intersection of two list means we need to take all those elements which are common to both of the initial lists and store them into another list. Only use using list-comprehension.
# 	Example 1:
#
# 	Input:
#
# 	lst1 = {15, 9, 10, 56, 23, 78, 5, 4, 9}
#
# 	lst2 = {9, 4, 5, 36, 47, 26, 10, 45, 87}
#
# 	Output:
#
# 	[9, 10, 4, 5]
#
# 	Example 2:
#
# 	Input:
#
# 	lst1 = {4, 9, 1, 17, 11, 26, 28, 54, 69}
#
# 	lst2 = {9, 9, 74, 21, 45, 11, 63, 28, 26}
#
# 	Output:
#
# 	[9, 11, 26, 28]

# %%
lst1 = {15, 9, 10, 56, 23, 78, 5, 4, 9}

lst2 = {9, 4, 5, 36, 47, 26, 10, 45, 87}
lst3=[i for i in lst1.intersection(lst2)]
print(sorted(lst3))
# Out:
# [4, 5, 9, 10]

# %%
lst1 = {4, 9, 1, 17, 11, 26, 28, 54, 69}

lst2 = {9, 9, 74, 21, 45, 11, 63, 28, 26}
lst4=[i for i in lst1 if i in lst2]
print(lst4)
# Out:
# [9, 11, 26, 28]

# %% [markdown]
# 13. Convert a list of Tuples into Dictionary.
#
# 	Example 1:
#
# 	Input:
#
# 	[("akash", 10), ("gaurav", 12), ("anand", 14), ("suraj", 20), ("akhil", 25), ("ashish", 30)]
#
# 	Output:
#
# 	{'akash': [10], 'gaurav': [12], 'anand': [14], 'suraj': [20], 'akhil': [25], 'ashish': [30]}
#
# 	Example 2:
#
# 	Input:
#
# 	[('A', 1), ('B', 2), ('C', 3)]
#
# 	Output:
#
# 	{'A': [1], 'B': [2], 'C': [3]}

# %%
l = [("akash", 10), ("gaurav", 12), ("anand", 14), ("suraj", 20), ("akhil", 25), ("ashish", 30)]
print(dict(l))
# Out:
# {'akash': 10, 'gaurav': 12, 'anand': 14, 'suraj': 20, 'akhil': 25, 'ashish': 30}

# %%
l=[('A', 1), ('B', 2), ('C', 3)]
print(dict(l))
# Out:
# {'A': 1, 'B': 2, 'C': 3}

# %%
l=[('A', 1), ('B', 2), ('C', 3)]
d = {}
for k,v in l:
  d[k]= [v]
print(d)
# Out:
# {'A': [1], 'B': [2], 'C': [3]}

# %%
l=[('A', 1), ('B', 2), ('C', 3)]
d = {}
for k,v in l:
  d[k]= [v]
print(d)
# Out:
# {'A': [1], 'B': [2], 'C': [3]}

# %% [markdown]
# 14. Write a Python function that takes a list and returns a new list with unique elements of the first list.
#
# 	Exercise 1:
#
# 	Input:
#
# 	[1,2,3,3,3,3,4,5]
#
# 	Output:
#
# 	[1, 2, 3, 4, 5]

# %%
l = [1,2,3,3,3,3,4,5]
d= set(l)
l=list(d)
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# 15.  Write a Python program to print the even numbers from a given list.
#
# 		Sample List : [1, 2, 3, 4, 5, 6, 7, 8, 9]
#
# 		Expected Result : [2, 4, 6, 8]

# %%
l=[1, 2, 3, 4, 5, 6, 7, 8, 9]
result=[i for i in l if i % 2 == 0]
print(result)
# Out:
# [2, 4, 6, 8]

# %% [markdown]
# 16. Write a Python function to check whether a number is perfect or not.¶
# 	A Perfect number is a number that is half the sum of all of its positive divisors (including itself).
#
# 	Example :
#
# 	The first perfect number is 6, because 1, 2, and 3 are its proper positive divisors, and 1 + 2 + 3 = 6.
# 	Equivalently, the number 6 is equal to half the sum of all its positive divisors: ( 1 + 2 + 3 + 6 ) / 2 = 6.
#
# 	The next perfect number is 28 = 1 + 2 + 4 + 7 + 14. This is followed by the perfect numbers 496 and 8128.

# %%
num = int(input('enter number to check perfect or not = '))
sum = 0
i = 1
while i <= num :
  if num %i == 0:
    sum = sum + i
  i+=1
sum = sum/2
if num == sum:
  print('perfect number',num)
else:
  print('Not a perfect number')
# Out:
# enter number to check perfect or not = 28
# perfect number 28

# %%
6/2
# Out:
# 3.0

# %% [markdown]
# 17. Write a Python function to concatenate any no of dictionaries to create a new one.
#
# 	Sample Dictionary :
#
# 	dic1={1:10, 2:20}
#
# 	dic2={3:30, 4:40}
#
# 	dic3={5:50,6:60}
#
# 	Expected Result : {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
def concat_dictionary(*x):
  """Python function to concatenate any no of dictionaries to create a new one"""
  concat = {}
  for i in x:
    concat.update(i)
  return concat

# %%
a=({1:10, 2:20})
b=({3:30, 4:40})
c=({5:50,6:60})
concat_dictionary(a,b,c)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %% [markdown]
# 18. Write a python function that receives a list of integers and prints out a histogram of bin size 10
#
# 	Input:
# 	[13,42,15,37,22,39,41,50]
#
# 	Output:
#
# 	{11-20:2,21-30:1,31-40:2,41-50:3}
