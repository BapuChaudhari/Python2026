# %% [markdown]
# 1. Write a Python program to create a class representing a Circle. Include methods to calculate its area and perimeter.

# %%
class Circle:

  def __init__(self,radius=1):
    self.radius = radius

  def area_circle(radius):
    area = 3.14 * radius * radius
    return area

  def perimeter_circle(radius):
    perimeter = 2*3.14*radius
    return perimeter

# %%
radius = 10
print(Circle.area_circle(radius))
print(Circle.perimeter_circle(radius))
# Out:
# 314.0
# 62.800000000000004

# %% [markdown]
# 2. Write a Python program to create a person class. Include attributes like name, country and date of birth. Implement a method to determine the person's age.

# %%
class PersonClass:
  def __init__(self,name,country,date_of_birth):
    self.name = name
    self.country = country
    self.date_of_birth = date_of_birth

  def person_age(self,date_of_birth):
    import datetime
    today_date = datetime.date.today()
    name = self.name
    country = self.country
    date_of_birth = self.date_of_birth

    age = today_date - date_of_birth
    return name,date_of_birth,age,country

# %%
import datetime
name = 'bapu'
country = 'india'
date_of_birth = datetime.date(1993,10,18)
print(PersonClass(name,country,date_of_birth).person_age(date_of_birth))
# Out:
# ('bapu', datetime.date(1993, 10, 18), datetime.timedelta(days=11859), 'india')

# %% [markdown]
# 3. Write a Python program to create a calculator class. Include methods for basic arithmetic operations.

# %%
class Calculator:
  def __init__(self,x=1,y=1):
    self.x = x
    self.y = y

  def __add__(self,x,y):
    return (x+y)

  def __sub__(self,x,y):
    return (x-y)

  def __mult__(self,x,y):
    return (x*y)

  def __trudiv__(self,x,y):
    return (x/y)

# %%
x=2
y=3
print(x+y)
print(x-y)
print(x*y)
print(x/y)
# Out:
# 5
# -1
# 6
# 0.6666666666666666

# %% [markdown]
# 4. Write a Python program to create a class that represents a shape. Include methods to calculate its area and perimeter. Implement subclasses for different shapes like circle, triangle, and square.

# %%
class Shape():
  def __init__(self):

# %% [markdown]
# 5. Write a Python program to create a class representing a binary search tree. Include methods for inserting and searching for elements in the binary tree.

# %% [markdown]
# 6. Write a Python program to create a class representing a stack data structure. Include methods for pushing and popping elements.

# %%
class StackDataStructure():

  def __init__(self):
    self.list1=[]

  def push(self,num=1):
    self.list1.append(num)

  def pop(self):
    self.list1.pop()

# %%
t=StackDataStructure()
t.push(10)
t.push(20)
t.push(40)
t.push(0)

t.push(100)
print(t.list1)
t.pop()
print(t.list1)
# Out:
# [10, 20, 40, 0, 100]
# [10, 20, 40, 0]

# %%
t=StackDataStructure()
t.push(10)
t.push(20)
t.push(40)
t.push(0)
print(t.list1)
t.pop()
print(t.list1)
# Out:
# [10, 20, 40, 0]
# [10, 20, 40]

# %% [markdown]
# 7. Write a Python program to create a class representing a linked list data structure. Include methods for displaying linked list data, inserting and deleting nodes.

# %%
# Node class
class Node():
    def __init__(self, data):
        self.data = data
        self.next = None


# Linked List class
class LinkedList():
    def __init__(self):
        self.head = None

    # Insert at the beginning
    def insert_at_beginning(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node

    # Insert at the end
    def insert_at_end(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            return

        temp = self.head
        while temp.next:
            temp = temp.next
        temp.next = new_node

    # Delete a node by value
    def delete(self, key):
        temp = self.head

        # If head node itself holds the key
        if temp and temp.data == key:
            self.head = temp.next
            temp = None
            return

        prev = None
        while temp and temp.data != key:
            prev = temp
            temp = temp.next

        # If key not present
        if temp is None:
            print("Value not found in list")
            return

        prev.next = temp.next
        temp = None

    # Display the linked list
    def display(self):
        temp = self.head
        if temp is None:
            print("Linked List is empty")
            return

        while temp:
            print(temp.data, end=" -> ")
            temp = temp.next
        print("None")


# Example usage
ll = LinkedList()

ll.insert_at_beginning(10)
ll.insert_at_beginning(5)
ll.insert_at_end(20)
ll.insert_at_end(30)

print("Linked List:")
ll.display()

ll.delete(20)
print("After deleting 20:")
ll.display()
# Out:
# Linked List:
# 5 -> 10 -> 20 -> 30 -> None
# After deleting 20:
# 5 -> 10 -> 30 -> None

# %% [markdown]
# 8. Write a Python program to create a class representing a shopping cart. Include methods for adding and removing items, and calculating the total price.

# %%
class ShoppingCart():
  def __init__(self):
    self.cart=[]
    self.price=[]

  def add_item(self,item,price):
    self.cart.append(item)
    self.price.append(price)

  def remove_item(self,item):
    temp = self.cart.index(item)
    self.cart.remove(item)

    self.price.pop(temp)

  def total_price(self):
    total_price = sum(self.price)
    return 'total price is {}'.format(total_price)

# %%
t1 = ShoppingCart()
t1.add_item('apple',100)
print(t1.cart)
print(t1.price)
t1.add_item('banana',200)
print(t1.cart)
print(t1.price)
t1.remove_item('apple')
print(t1.cart)
print(t1.price)
print(t1.total_price())
# Out:
# ['apple']
# [100]
# ['apple', 'banana']
# [100, 200]
# ['banana']
# [200]
# total price is 200

# %%
l=['a','b']
l.append('d')
print(l)
# Out:
# ['a', 'b', 'd']

# %% [markdown]
# 9. Write a Python program to create a class representing a stack data structure. Include methods for pushing, popping and displaying elements.

# %%
# repeated question

# %% [markdown]
# 10. Write a Python program to create a class representing a queue data structure. Include methods for enqueueing and dequeueing elements.

# %% [markdown]
# 11. Write a Python program to create a class representing a bank. Include methods for managing customer accounts and transactions.
#
# 	Create a Python class called BankAccount which represents a bank account, having as attributes: accountNumber (numeric type), name (name of the account owner as string type), balance.
#
# 	Create a constructor with parameters: accountNumber, name, balance.
#
# 	Create a Deposit() method which manages the deposit actions.
#
# 	Create a Withdrawal() method which manages withdrawals actions.
#
# 	Create an bankFees() method to apply the bank fees with a percentage of 5% of the balance account.
#
# 	Create a display() method to display account details. Give the complete code for the BankAccount class.

# %%
class BankAccount():
  def __init__(self,accountNumber,name,balance):
    self.accountNumber = accountNumber
    self.name = name
    self.balance = balance
    print(type(self.balance))
    self.menu()

  def __str__(self):
    return 'accountNumber = {},name = {},balance = {}'.format(self.accountNumber,self.name,self.balance)

  def menu(self):
    print(''' \n enter your choice
    1.enter for deposit
    2.For withdrawl
    3.For bank fees
    4.For display
    5.for exit
    ''')

    choice = int(input('enter your choice = '))

    if choice == 1:
      amount = int(input('enter amount to deposit = '))
      print(self.deposit(amount))
      self.deposit(amount)

    elif choice == 2:
      print(self.withdrawl())
    elif choice == 3:
      self.bankFees()
    elif choice == 4:
      self.display()

    elif choice == 5:
      exit()
    else:
      print('enter valid responce')
      self.menu()



  def deposit(self,amount):
    #amount = int(input('enter amount to deposit = '))

    self.balance = self.balance + amount

    return self.balance



  def withdrawl(self):
    amount = int(input('enter amount to withdraw = '))
    self.balance = self.balance - amount
    return self.balance


  def bankFees(self):
    self.balance = self.balance - 0.05*self.balance
    return self.balance


  def display(self):
    print('accountNumber = ',self.accountNumber)
    print('name = ',self.name)
    print('balance = ',self.balance)

# %%
b=BankAccount(21,'bapu',10000)
print(b.deposit)
# Out:
# <class 'int'>
#
#  enter your choice
#     1.enter for deposit
#     2.For withdrawl
#     3.For bank fees
#     4.For display
#     5.for exit
#
# enter your choice = 2
# enter amount to withdraw = 5000
# 5000
# <bound method BankAccount.deposit of <__main__.BankAccount object at 0x79fe39271a90>>

# %% [markdown]
# 12. Build a flashcard using class in python. A flashcard is a card having information on both sides, which can be used as an aid in memoization. Flashcards usually have a question on one side and an answer on the other.
#
# 	Example 1:
#
# 	Approach:
#
# 	Create a class named FlashCard.
#
# 	Initialize dictionary fruits using init() method. Here you have to define fruit name as key and it's color as value. E.g., {"Banana": "yellow", "Strawberries": "pink"}
#
# 	Now randomly choose a pair from fruits by using random module and store the key in variable fruit and value in variable color.
#
# 	Now prompt the user to answer the color of the randomly chosen fruit.
#
# 	If correct print correct else print wrong.
#
# 	Output:
#
# 	welcome to fruit quiz
#
# 	What is the color of Strawberries
#
# 	pink
#
# 	Correct answer
#
# 	Enter 0, if you want to play again: 0
#
# 	What is the color of watermelon
#
# 	green
#
# 	Correct answer
#
# 	Enter 0, if you want to play again: 1

# %%
import random

class FlashCard():
  def __init__(self):
    self.fruits = {'banana':'yellow',
                   'strawberries':'pink',
                   'apple':'red',
                   'orange':'orange',
                   'watermelon':'green'}

  def play(self):
    score = 0
    print('\n Welcome to quiz lets paly.............')
    while True:

      #randomly choose fruit
      fruit,colour = random.choice(list(self.fruits.items()))

      print('what is the colour of {} ?'.format(fruit))

      answer = input('enter your answer = ')

      if answer == colour:
        print('correct answer')
        score = score + 1
      else:
        print('wrong answer')
      print('enter y for play again')
      choice = input('enter your choice = ')
      if choice != 'y':

        print('thankss for playing...............')
        print('your score is {}'.format(score))
        break

# %%
play =FlashCard()
play.play()
# Out:
#  Welcome to quiz lets paly.............
# what is the colour of orange ?
# enter your answer = orange
# correct answer
# enter y for play again
# enter your choice = y
# what is the colour of orange ?
# enter your answer = orange
# correct answer
# enter y for play again
# enter your choice = y
# what is the colour of banana ?
# enter your answer = yellow
# correct answer
# enter y for play again
# enter your choice = d
# thankss for playing...............
# your score is 3

# %% [markdown]
# 13. TechWorld, a technology training center, wants to allocate courses for instructors. An instructor is identified by name, technology skills, experience and average feedback. An instructor is allocated a course, if he/she satisfies the below two conditions:
#
# 	eligibility criteria:
#
# 	if experience is more than 3 years, average feedback should be 4.5 or more
#
# 	if experience is 3 years or less, average feedback should be 4 or more
#
# 	he/she should posses the technology skill for the course
# 	Identify the class name and attributes to represent instructors. Write a Python program to implement the class chosen with its attributes and methods.
#
# 	Note:
#
# 	Consider all instance variables to be private and methods to be public.
#
# 	An instructor may have multiple technology skills, so consider instance variable, technology_skill to be a list.
#
# 	check_eligibility(): Return true if eligibility criteria is satisfied by the instructor. Else, return false
#
# 	allocate_course(technology): Return true if the course which requires the given technology can be allocated to the instructor. Else, return false.
#
# 	Represent a few objects of the class, initialize instance variables using setter methods, invoke appropriate methods and test your program.

# %%
class Instructor():
    def __init__(self):
        self.__name = None
        self.__technology_skills = []
        self.__experience = 0
        self.__avg_feedback = 0.0

    def setter(self, name, technology_skills, experience, avg_feedback):
        self.__name = name
        self.__technology_skills = technology_skills
        self.__experience = experience
        self.__avg_feedback = avg_feedback

    def getter(self):
        return self.__name


    # Check eligibility
    def check_eligibility(self):
        if self.__experience > 3:
            return self.__avg_feedback >= 4.5
        else:
            return self.__avg_feedback >= 4

    # Allocate course
    def allocate_course(self, technology):
        return self.check_eligibility() and technology in self.__technology_skills


# -------- Input --------
n = int(input("Enter number of instructors: "))
instructors = []

for i in range(n):
    print("\nEnter details for Instructor", i+1)

    inst = Instructor()

    name = input("Enter name: ")
    skills = input("Enter technology skills (comma separated): ").split(',')
    technology_skills = [s.strip() for s in skills]

    experience = int(input("Enter experience (years): "))
    avg_feedback = float(input("Enter average feedback: "))

    inst.setter(name, technology_skills, experience, avg_feedback)
    instructors.append(inst)

technology = input("\nEnter technology required for course: ")

# -------- Output --------
for inst in instructors:
    print(f"\nInstructor: {inst.getter()}")

    if inst.check_eligibility():
        print("Eligible")
    else:
        print("Not Eligible")

    if inst.allocate_course(technology):
        print(f"Allocated course: {technology}")
    else:
        print(f"Cannot allocate course: {technology}")
# Out:
# Enter number of instructors: 2
#
# Enter details for Instructor 1
# Enter name: parag
# Enter technology skills (comma separated): python,java
# Enter experience (years): 5
# Enter average feedback: 4
#
# Enter details for Instructor 2
# Enter name: rekha
# Enter technology skills (comma separated): c++,c
# Enter experience (years): 3
# Enter average feedback: 5.6
#
# Enter technology required for course: c
#
# Instructor: parag
# Not Eligible
# Cannot allocate course: c
#
# Instructor: rekha
# Eligible
# Allocated course: c

# %% [markdown]
# 14. Write a program that uses datetime module within a class. Enter manufacturing date and expiry date of the product. The program must display the years, months and days that are left for expiry.

# %%
from datetime import datetime, timedelta
today_date = datetime.now()
print(today_date.date())


mfg_date = input('enter mfg date(yyyy-mm-dd) = ')

mfg_date = datetime.strptime(mfg_date,'%Y-%m-%d')

exp_date = input('enter exp date(yyyy-mm-dd) = ')
exp_date = datetime.strptime(exp_date,'%Y-%m-%d')
left_date = exp_date - today_date
print(left_date)
# Out:
# 2026-04-16
# enter mfg date(yyyy-mm-dd) = 2025-10-03
# enter exp date(yyyy-mm-dd) = 2027-10-03
# 534 days, 14:02:25.557571

# %% [markdown]
# 15. A university wants to automate their admission process. Students are admitted based on the marks scored in the qualifying exam. A student is identified by student id, age and marks in qualifying exam. Data are valid, if:
#
# 	Age is greater than 20
# 	Marks is between 0 and 100 (both inclusive)
# 	A student qualifies for admission, if
#
# 	Age and marks are valid and
# 	Marks is 65 or more
# 	Write a python program to represent the students seeking admission in the university.

# %%
class University():
  def __init__(self,student_id,age,marks):
    self.student_id = student_id
    self.age = age
    self.marks = marks

  def admission(self):
    if self.age > 20 and self.marks >=65:
      return f"student {self.student_id} is eligible for taking admission "

    else:
      return f"Not eligible for admission"

# %%
stu1 = University(1,21,70)
print(stu1.admission())
stu2 = University(2,19,70)
print(stu2.admission())
stu3 = University(3,21,60)
stu3.admission()
# Out:
# student 1 is eligible for taking admission
# Not eligible for admission
# 'Not eligible for admission'

# %% [markdown]
# 16. Ice-Cream Scoops and Bowl shop
#
# 	Create a class Scoop which has one public property flavor and one private proptery price. Take flavor values during object creation.
#
# 	Create a class Bowl with private prperty scoop_list which will have list of scoopd object.
#
# 	Create a method add_scoops in Bowl class which will add any no of Scoop objects given as parameter and store it in scoops_list.
#
# 	Make getter and setter method for price property.
#
# 	Make a method display to display flavour and price of each Scoop in scoop_list and print total price of the bowl by adding all flavour scoops prices.
#
# 	Make a method sold in both Scoop class and Bowl class to print no of quantity sold.

# %%
class Scoop():
  scoop_count = 0
  def __init__(self,flavour,price):
    self.flavour = flavour
    self.__price = price
    Scoop.scoop_count += 1

  def set_price(self,price):
    self.__price = price


  def get_price(self):
    return self.__price

  def total_scoop(self):
    return Scoop.scoop_count

class Bowl():
  bowl_count = 0
  def __init__(self):
    self.__scoop_list = []
    Bowl.bowl_count += 1

  def get_scoop_count(self):
    return Bowl.bowl_count

  def add_scoops(self,*scoops):
    for scoop in scoops:
      self.__scoop_list.append(scoop)



  def display(self):
    for scoop in self.__scoop_list:
      print(f"Flavour of scoop is {scoop.flavour} and price is {scoop.get_price()}")

  def total_price(self):
    total_price = 0
    for scoop in self.__scoop_list:
      total_price += scoop.get_price()
    return total_price

  def total_bowl(self):
    return Bowl.bowl_count

# %%
s1 = Scoop('vanilla',50)
s2 = Scoop('strawberry',55)
s3 = Scoop('chocolate',60)
print(s1.flavour,s1.get_price())
print(s2.flavour,s2.get_price())
print(s3.flavour,s3.get_price())


a1 = Bowl()
a1.add_scoops(s1,s2,s3)
a1.display()
print(a1.total_price())
print(s1.total_scoop())
print(a1.total_bowl())


print(a1.get_scoop_count())
# Out:
# vanilla 50
# strawberry 55
# chocolate 60
# Flavour of scoop is vanilla and price is 50
# Flavour of scoop is strawberry and price is 55
# Flavour of scoop is chocolate and price is 60
# 165
# 20
# 7
# 7

# %% [markdown]
# 17. Create a Bus child class that inherits from the Vehicle class. The default fare charge of any vehicle is seating capacity * 100. If Vehicle is Bus instance, we need to add an extra 10% on full fare as a maintenance charge. So total fare for bus instance will become the final amount = total fare + 10% of the total fare.
#
# Note: The bus seating capacity is 50. so the final fare amount should be 5500. You need to override the fare() method of a Vehicle class in Bus class.

# %%
class Vehicle():
  def __init__(self,seating_capacity):
    self.seating_capacity = seating_capacity


  def fare(self):
    return self.seating_capacity * 100

class Bus(Vehicle):
  def __init__(self):
    super().__init__(50)

  def bus_fare(self):
    total_fare = super().fare()
    maintenance = .1*total_fare
    return (total_fare + maintenance)

# %%
bus=Bus()
print(bus.fare())
bus.bus_fare()
print("Total Bus Fare:", bus.bus_fare())
# Out:
# 5000
# Total Bus Fare: 5500.0

# %%
class Vehicle():
    def __init__(self, seating_capacity):
        self.seating_capacity = seating_capacity

    def fare(self):
        return self.seating_capacity * 100


class Bus(Vehicle):
    def fare(self):
        total_fare = super().fare()
        maintenance = 0.1 * total_fare
        return total_fare + maintenance

# %%
bus = Bus(50)
print("Total Bus Fare:", bus.fare())
# Out:
# Total Bus Fare: 5500.0

# %% [markdown]
# 18. Write a Python class Employee with attributes like emp_id, emp_name, emp_salary, and emp_department and methods like calculate_emp_salary, emp_assign_department, and print_employee_details.
#
# 	Sample Employee Data:
#
# 	"ADAMS", "E7876", 50000, "ACCOUNTING"
#
# 	"JONES", "E7499", 45000, "RESEARCH"
#
# 	"MARTIN", "E7900", 50000, "SALES"
#
# 	"SMITH", "E7698", 55000, "OPERATIONS"
#
# 	Use 'assign_department' method to change the department of an employee.
# 	Use 'print_employee_details' method to print the details of an employee.
#
# 	Use 'calculate_emp_salary' method takes two arguments: salary and hours_worked, which is the number of hours worked by the employee. If the number of hours worked is more than 50, the method computes overtime and adds it to the salary. Overtime is calculated as following formula:
#
# 	overtime = hours_worked - 50
#
# 	Overtime amount = (overtime * (salary / 50))

# %%
class Employee():
  def __init__(self, emp_id, emp_name, emp_salary, emp_department):
    self.emp_id = emp_id
    self.emp_name = emp_name
    self.emp_salary = emp_salary
    self.emp_department = emp_department

  def calculate_emp_salary(self, hours_worked):
    if hours_worked > 50:
      overtime = hours_worked - 50
      overtime_amount = overtime * (self.emp_salary / 50)
      return self.emp_salary + overtime_amount
    else:
      return self.emp_salary

  def emp_assign_department(self, emp_department):
    self.emp_department = emp_department

  def print_employee_details(self, hours_worked):
    print(f"Employee Id = {self.emp_id}")
    print(f"Employee Name = {self.emp_name}")
    print(f"Employee Salary = {self.calculate_emp_salary(hours_worked)}")
    print(f"Employee Department = {self.emp_department}")

# %%
e1 ="ADAMS", "E7876", 50000, "ACCOUNTING"

e2 = "E7499","JONES",  45000, "RESEARCH"

e3 = "E7900","MARTIN",  50000, "SALES"

e4 = "E7698","SMITH",  55000, "OPERATIONS"

emp = Employee("E7876","ADAMS",  50000, "ACCOUNTING")
emp.calculate_emp_salary(55)
emp.emp_assign_department("OPERATIONS")
emp.print_employee_details(55)
# Out:
# Employee Id = E7876
# Employee Name = ADAMS
# Employee Salary = 55000.0
# Employee Department = OPERATIONS

# %% [markdown]
# 19. Write a Python class Restaurant with attributes like menu_items, book_table, and customer_orders, and methods like add_item_to_menu, book_tables, and customer_order.
#
# 	Perform the following tasks now:
#
# 	Now add items to the menu.
#
# 	Make table reservations.
#
# 	Take customer orders.
#
# 	Print the menu.
#
# 	Print table reservations.
#
# 	Print customer orders.
#
# 	Note: Use dictionaries and lists to store the data.

# %%
class Restaurant:
    def __init__(self):
        # {item_name: price}
        self.menu_items = {}
        # list of booked tables
        self.book_table = []
        # list of orders
        self.customer_orders = []

    # Add item to menu
    def add_item_to_menu(self, item, price):
        self.menu_items[item] = price

    # Book table
    def book_tables(self, table_number):
        self.book_table.append(table_number)

    # Take customer order
    def customer_order(self, table_number, items):
        order = {
            "table": table_number,
            "items": items
        }
        self.customer_orders.append(order)

    # Print menu
    def print_menu(self):
        print("\n--- MENU ---")
        for item, price in self.menu_items.items():
            print(f"{item}: ₹{price}")

    # Print table reservations
    def print_table_reservations(self):
        print("\n--- TABLE RESERVATIONS ---")
        for table in self.book_table:
            print(f"Table {table} is reserved")

    # Print customer orders
    def print_customer_orders(self):
        print("\n--- CUSTOMER ORDERS ---")
        for order in self.customer_orders:
            print(f"Table {order['table']} ordered: {', '.join(order['items'])}")

# %%
restaurant = Restaurant()

restaurant.add_item_to_menu("Pizza", 250)
restaurant.add_item_to_menu("Burger", 120)
restaurant.add_item_to_menu("Pasta", 200)

restaurant.book_tables(1)
restaurant.book_tables(2)


restaurant.customer_order(1, ["Pizza"])
restaurant.customer_order(2, ["Pasta"])


restaurant.print_menu()
restaurant.print_table_reservations()
restaurant.print_customer_orders()
# Out:
# --- MENU ---
# Pizza: ₹250
# Burger: ₹120
# Pasta: ₹200
#
# --- TABLE RESERVATIONS ---
# Table 1 is reserved
# Table 2 is reserved
#
# --- CUSTOMER ORDERS ---
# Table 1 ordered: Pizza
# Table 2 ordered: Pasta

# %% [markdown]
# 20. Write a Python class BankAccount with attributes like account_number, balance, date_of_opening and customer_name, and methods like deposit, withdraw, and check_balance.

# %%
class BankAccount:
    def __init__(self, account_number, customer_name, balance, date_of_opening):
        self.account_number = account_number
        self.customer_name = customer_name
        self.balance = balance
        self.date_of_opening = date_of_opening


    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"Deposited ₹{amount}")
        else:
            print("Invalid deposit amount")


    def withdraw(self, amount):
        if amount <= 0:
            print("Invalid withdrawal amount")
        elif amount > self.balance:
            print("Insufficient balance")
        else:
            self.balance -= amount
            print(f"Withdrawn ₹{amount}")


    def check_balance(self):
        print(f"Current Balance: ₹{self.balance}")



    def display_details(self):
        print("\n***** Account Details *****")
        print(f"Account Number: {self.account_number}")
        print(f"Customer Name: {self.customer_name}")
        print(f"Balance: ₹{self.balance}")
        print(f"Date of Opening: {self.date_of_opening}")

# %%
acc1 = BankAccount(12345, "bapu", 10000, "01-01-2024")

acc1.display_details()
acc1.deposit(5000)
acc1.withdraw(3000)
acc1.check_balance()
# Out:
# ***** Account Details *****
# Account Number: 12345
# Customer Name: bapu
# Balance: ₹10000
# Date of Opening: 01-01-2024
# Deposited ₹5000
# Withdrawn ₹3000
# Current Balance: ₹12000

# %% [markdown]
# 21. Write a Python class Inventory with attributes like item_id, item_name, stock_count, and price, and methods like add_item, update_item, and check_item_details.

# %%
class Inventory:
    def __init__(self):
        self.items = {}


    def add_item(self, item_id, item_name, stock_count, price):
        if item_id in self.items:
            print("Item already exists")
        else:
            self.items[item_id] = {
                "name": item_name,
                "stock": stock_count,
                "price": price
            }
            print("Item added successfully")


    def update_item(self, item_id, stock_count=None, price=None):
        if item_id in self.items:
            if stock_count is not None:
                self.items[item_id]["stock"] = stock_count
            if price is not None:
                self.items[item_id]["price"] = price
            print("Item updated successfully")
        else:
            print("Item not found")


    def check_item_details(self, item_id):
        if item_id in self.items:
            item = self.items[item_id]
            print("\n--- Item Details ---")
            print(f"Item ID: {item_id}")
            print(f"Name: {item['name']}")
            print(f"Stock: {item['stock']}")
            print(f"Price: ₹{item['price']}")
        else:
            print("Item not found")

# %%
inv = Inventory()

inv.add_item(101, "Laptop", 10, 50000)
inv.add_item(102, "Mouse", 50, 500)

inv.update_item(101, stock_count=8, price=48000)


inv.check_item_details(101)
# Out:
# Item added successfully
# Item added successfully
# Item updated successfully
#
# --- Item Details ---
# Item ID: 101
# Name: Laptop
# Stock: 8
# Price: ₹48000
